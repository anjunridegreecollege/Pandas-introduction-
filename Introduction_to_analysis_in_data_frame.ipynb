# %% [markdown]
# <a href="https://colab.research.google.com/github/anjunridegreecollege/Pandas-introduction-/blob/main/Introduction_to_analysis_in_data_frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
len(a1)
# Out:
# 0

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
a1
# Out:
# [54,
#  88,
#  49,
#  38,
#  42,
#  50,
#  46,
#  73,
#  23,
#  67,
#  100,
#  99,
#  14,
#  31,
#  54,
#  51,
#  45,
#  97,
#  8,
#  56,
#  67,
#  3,
#  81,
#  73,
#  70,
#  62,
#  59,
#  6,
#  70,
#  100,
#  58,
#  11,
#  56,
#  34,
#  32,
#  9,
#  95,
#  39,
#  29,
#  37,
#  27,
#  70,
#  49,
#  88,
#  95,
#  0,
#  95,
#  70,
#  89,
#  35,
#  38,
#  40,
#  95,
#  43,
#  52,
#  97,
#  89,
#  72,
#  35,
#  50,
#  72,
#  84,
#  67,
#  70,
#  79,
#  54,
#  6,
#  50,
#  44,
#  28,
#  33,
#  93,
#  70,
#  91,
#  98,
#  32,
#  16,
#  1,
#  98,
#  34,
#  4,
#  97,
#  19,
#  62,
#  10,
#  80,
#  9,
#  2,
#  97,
#  74,
#  8,
#  50,
#  23,
#  100,
#  36,
#  3,
#  9,
#  30,
#  6,
#  18,
#  52,
#  32,
#  80,
#  9,
#  35,
#  100,
#  53,
#  49,
#  61,
#  16,
#  52,
#  87,
#  74,
#  60,
#  28,
#  32,
#  45,
#  38,
#  50,
#  86,
#  10,
#  75,
#  9,
#  73,
#  84,
#  50,
#  16,
#  30,
#  80,
#  44,
#  51,
#  7,
#  72,
#  72,
#  89,
#  82,
#  63,
#  80,
#  97,
#  90,
#  49,
#  18,
#  1,
#  24,
# ...

# %%
df ={
    'grade':a1,
    'weight':a2,
    'friends':a3,
    'cousins':a4,
    'projects':a5
}

# %%
df
# Out:
# {'grade': [54,
#   88,
#   49,
#   38,
#   42,
#   50,
#   46,
#   73,
#   23,
#   67,
#   100,
#   99,
#   14,
#   31,
#   54,
#   51,
#   45,
#   97,
#   8,
#   56,
#   67,
#   3,
#   81,
#   73,
#   70,
#   62,
#   59,
#   6,
#   70,
#   100,
#   58,
#   11,
#   56,
#   34,
#   32,
#   9,
#   95,
#   39,
#   29,
#   37,
#   27,
#   70,
#   49,
#   88,
#   95,
#   0,
#   95,
#   70,
#   89,
#   35,
#   38,
#   40,
#   95,
#   43,
#   52,
#   97,
#   89,
#   72,
#   35,
#   50,
#   72,
#   84,
#   67,
#   70,
#   79,
#   54,
#   6,
#   50,
#   44,
#   28,
#   33,
#   93,
#   70,
#   91,
#   98,
#   32,
#   16,
#   1,
#   98,
#   34,
#   4,
#   97,
#   19,
#   62,
#   10,
#   80,
#   9,
#   2,
#   97,
#   74,
#   8,
#   50,
#   23,
#   100,
#   36,
#   3,
#   9,
#   30,
#   6,
#   18,
#   52,
#   32,
#   80,
#   9,
#   35,
#   100,
#   53,
#   49,
#   61,
#   16,
#   52,
#   87,
#   74,
#   60,
#   28,
#   32,
#   45,
#   38,
#   50,
#   86,
#   10,
#   75,
#   9,
#   73,
#   84,
# ...

# %%
pip install pandas

# %%
import pandas as pd

# %%
df1=pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       54      65       17        9        23
# 1       88      59       10        8        78
# 2       49      65       20        9        48
# 3       38      64       18        5        27
# 4       42      67       11       10        76
# ..     ...     ...      ...      ...       ...
# 995     92      59       12        8        29
# 996     75      67       19        6        51
# 997     85      54       12        6        56
# 998     60      59       19        7        22
# 999     18      61       16        9        54
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins    projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     51.338000    59.777000    15.109000     7.473000    50.10600
# std      29.724389     5.917287     3.125842     1.700636    17.68631
# min       0.000000    50.000000    10.000000     5.000000    20.00000
# 25%      26.000000    55.000000    12.000000     6.000000    35.00000
# 50%      52.000000    60.000000    15.000000     7.000000    50.00000
# 75%      78.000000    65.000000    18.000000     9.000000    66.00000
# max     100.000000    70.000000    20.000000    10.000000    80.00000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 0       54      65       17        9        23
# 2       49      65       20        9        48
# 3       38      64       18        5        27
# 5       50      53       16        7        40
# 6       46      66       17        7        74
# ..     ...     ...      ...      ...       ...
# 991     63      67       19        5        41
# 992      2      70       16       10        30
# 996     75      67       19        6        51
# 998     60      59       19        7        22
# 999     18      61       16        9        54
#
# [474 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       54      65       17        9        23
# 1       88      59       10        8        78
# 7       73      53       16        9        47
# 9       67      60       16        7        73
# 10     100      65       15        9        57
# ..     ...     ...      ...      ...       ...
# 994     71      55       15        9        28
# 995     92      59       12        8        29
# 996     75      67       19        6        51
# 997     85      54       12        6        56
# 998     60      59       19        7        22
#
# [508 rows x 5 columns]

# %%
df1[friend15&grade50].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 51     57      20       9        75          1
#        66      20       8        21          1
# 84     55      16       7        40          1
#        61      20       8        46          1
#        68      17       5        29          1
#                                             ..
# 72     53      19       5        32          1
#        56      20       7        69          1
# 73     53      16       9        47          1
#        57      16       8        47          1
# 100    64      18       10       56          1
# Name: count, Length: 240, dtype: int64

# %%
df1[friend15&grade50]['weight'].value_counts()
# Out:
# weight
# 53    20
# 66    18
# 67    17
# 52    16
# 61    16
# 50    14
# 60    12
# 57    12
# 51    12
# 58    11
# 59    11
# 55    11
# 69    11
# 68    10
# 65     9
# 54     9
# 63     8
# 56     7
# 70     7
# 62     6
# 64     3
# Name: count, dtype: int64

# %%
df1[friend15&grade50]['friends']
# Out:
# 0      17
# 7      16
# 9      16
# 14     16
# 15     20
#        ..
# 978    19
# 988    19
# 991    19
# 996    19
# 998    19
# Name: friends, Length: 240, dtype: int64

# %%
df1[friend15&grade50]['grade']
# Out:
# 0      54
# 7      73
# 9      67
# 14     54
# 15     51
#        ..
# 978    92
# 988    62
# 991    63
# 996    75
# 998    60
# Name: grade, Length: 240, dtype: int64

# %%
df1[friend15&grade50]['weight'].value_counts()
# Out:
# weight
# 53    20
# 66    18
# 67    17
# 52    16
# 61    16
# 50    14
# 60    12
# 57    12
# 51    12
# 58    11
# 59    11
# 55    11
# 69    11
# 68    10
# 65     9
# 54     9
# 63     8
# 56     7
# 70     7
# 62     6
# 64     3
# Name: count, dtype: int64

# %%
pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15&grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1[friend15&grade50].plot(x='grade',y='projects')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15&grade50].plot(x='grade',y='projects',kind='bar')
# Out:
# <Axes: xlabel='grade'>

# %%
df1[friend15&grade50].plot(x='grade',y='projects',kind='barh')
# Out:
# <Axes: ylabel='grade'>
